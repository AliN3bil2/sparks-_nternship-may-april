# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 

from sklearn import metrics

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %% [markdown]
# <h>LOADING THE DATA</h>

# %%
# Read data from URL
data = pd.read_csv("http://bit.ly/w-data")

# %% [markdown]
# <h>DATA PREPROCESSING</h>

# %%
data.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
data.describe().style.background_gradient()
# Out:
# <style type="text/css">
# #T_944d5_row0_col0, #T_944d5_row7_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_944d5_row0_col1 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_944d5_row1_col0 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_944d5_row1_col1 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_944d5_row2_col0 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_944d5_row2_col1 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_944d5_row3_col0, #T_944d5_row3_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_944d5_row4_col0 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_944d5_row4_col1 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_944d5_row5_col0 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_944d5_row5_col1 {
#   background-color: #a2bcda;
#   color: #000000;
# }
# #T_944d5_row6_col0 {
#   background-color: #cccfe5;
#   color: #000000;
# }
# #T_944d5_row6_col1 {
#   background-color: #0771b1;
#   color: #f1f1f1;
# }
# #T_944d5_row7_col0 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# </style>
# <table id="T_944d5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_944d5_level0_col0" class="col_heading level0 col0" >Hours</th>
#       <th id="T_944d5_level0_col1" class="col_heading level0 col1" >Scores</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_944d5_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_944d5_row0_col0" class="data row0 col0" >25.000000</td>
#       <td id="T_944d5_row0_col1" class="data row0 col1" >25.000000</td>
#     </tr>
#     <tr>
#       <th id="T_944d5_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_944d5_row1_col0" class="data row1 col0" >5.012000</td>
#       <td id="T_944d5_row1_col1" class="data row1 col1" >51.480000</td>
#     </tr>
#     <tr>
#       <th id="T_944d5_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_944d5_row2_col0" class="data row2 col0" >2.525094</td>
#       <td id="T_944d5_row2_col1" class="data row2 col1" >25.286887</td>
#     </tr>
#     <tr>
#       <th id="T_944d5_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_944d5_row3_col0" class="data row3 col0" >1.100000</td>
#       <td id="T_944d5_row3_col1" class="data row3 col1" >17.000000</td>
#     </tr>
#     <tr>
#       <th id="T_944d5_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_944d5_row4_col0" class="data row4 col0" >2.700000</td>
#       <td id="T_944d5_row4_col1" class="data row4 col1" >30.000000</td>
#     </tr>
#     <tr>
#       <th id="T_944d5_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_944d5_row5_col0" class="data row5 col0" >4.800000</td>
#       <td id="T_944d5_row5_col1" class="data row5 col1" >47.000000</td>
#     </tr>
#     <tr>
#       <th id="T_944d5_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_944d5_row6_col0" class="data row6 col0" >7.400000</td>
#       <td id="T_944d5_row6_col1" class="data row6 col1" >75.000000</td>
#     </tr>
#     <tr>
#       <th id="T_944d5_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_944d5_row7_col0" class="data row7 col0" >9.200000</td>
#       <td id="T_944d5_row7_col1" class="data row7 col1" >95.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
data.info
# Out:
# <bound method DataFrame.info of     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# 5     1.5      20
# 6     9.2      88
# 7     5.5      60
# 8     8.3      81
# 9     2.7      25
# 10    7.7      85
# 11    5.9      62
# 12    4.5      41
# 13    3.3      42
# 14    1.1      17
# 15    8.9      95
# 16    2.5      30
# 17    1.9      24
# 18    6.1      67
# 19    7.4      69
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86>

# %%
data.isnull().sum()
# Out:
# Hours     0
# Scores    0
# dtype: int64

# %% [markdown]
# <h>CORRELATION</h>

# %%
plt.figure(figsize=(14, 14))
corr=data.corr().round()
corr=np.abs(corr)
sns_plot=sns.heatmap(corr, annot=True)

# %%
plt.figure(figsize=(14, 10))
sns.regplot(data=data, x="Hours", y="Scores",
            color='gray', line_kws={'color': 'black'})
# Out:
# <Axes: xlabel='Hours', ylabel='Scores'>

# %%
# Split the data into training and testing sets
x = data.iloc[:, :-1]  # First column and all rows
y = data.iloc[:, -1]   # Last column and all rows
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.4, random_state=0)

# %%
# Create and train a linear regression model
linear_reg = LinearRegression()
linear_reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
line = linear_reg.coef_*x+linear_reg.intercept_
plt.figure(figsize=(14, 10))
plt.scatter(x, y)
plt.scatter(x,y, c='grey', label='Specific Data Point')

plt.plot(x, line, color='black', label='Linear Regression Line')
plt.xlabel("Hours")
plt.ylabel("Scores")
# Out:
# Text(0, 0.5, 'Scores')

# %%
# Calculate accuracy on the test set
accuracy = linear_reg.score(x_test, y_test)

# %%
# Make predictions on the test set
y_pred = linear_reg.predict(x_test)

print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.956640847232559

# %%
y_test = list(y_test)
plt.plot(y_test, color='blue', label='Actual Value')
plt.plot(y_pred, color='green', label='Predicted Value')
plt.title('Actualvs Prediction')
plt.xlabel('Number of Hours')
plt.ylabel('Scores')
# Out:
# Text(0, 0.5, 'Scores')

# %%
print('PREDICT,ACTUAL')
for i, j in zip(y_pred, y_test):
    print(f'i={i},j={j}')
# Out:
# PREDICT,ACTUAL
# i=15.947761797680114,j=20
# i=32.77394722792941,j=27
# i=74.34452299678061,j=69
# i=25.845517933120874,j=30
# i=59.49788879361947,j=62
# i=38.71260090919387,j=35
# i=19.90686425185642,j=24
# i=78.30362545095691,j=86
# i=69.39564492906023,j=76
# i=11.98865934350381,j=17

# %%
print('MSE :',metrics.mean_absolute_percentage_error(y_pred,y_test))
print('R2_score :',metrics.r2_score(y_pred,y_test))
# Out:
# MSE : 0.16179357249105886
# R2_score : 0.9554256587556441
